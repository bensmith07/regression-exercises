# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import env
import wrangle
import explore

# %%
def acquire_mall_customers_data():
    sql = '''SELECT * FROM customers'''
    url = env.get_db_url('mall_customers')
    df = pd.read_sql(sql, url)
    return df

# %%
df = acquire_mall_customers_data()

# %%
df = df.drop(columns='customer_id')

# %%
target = 'spending_score'
features = [col for col in df.columns if col != target]

# %%
train, test, validate = wrangle.train_test_validate_split(df)
# Out:
# train	 n = 112
# test	 n = 40
# validate n = 48

# %%
train.head(3)
# Out:
#      gender  age  annual_income  spending_score
# 130    Male   47             71               9
# 62   Female   67             47              52
# 13   Female   24             20              77

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 130 to 185
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          112 non-null    object
#  1   age             112 non-null    int64
#  2   annual_income   112 non-null    int64
#  3   spending_score  112 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 4.4+ KB

# %%
explore.plot_variable_pairs(train)
