# %%
import wrangle

# %%
df = wrangle.wrangle_zillow()
# Out:
# Reading from local CSV...

# %%
df
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 0               4.0          3.0                        2090.0
# 1               5.0          3.0                        2479.0
# 2               4.0          2.0                        2057.0
# 3               4.0          3.0                        2423.0
# 4               4.0          3.0                        2226.0
# ...             ...          ...                           ...
# 2148357         4.0          3.0                        2143.0
# 2148358         4.0          2.5                        2210.0
# 2148359         3.0          1.0                        1204.0
# 2148360         4.0          2.0                        1708.0
# 2148361         3.0          2.0                        2004.0
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 0                 615000.0     1973.0    8625.75  6037.0
# 1                 531642.0     1973.0    6722.67  6037.0
# ...

# %%
df.isnull().sum()
# Out:
# bedroomcnt                      0
# bathroomcnt                     0
# calculatedfinishedsquarefeet    0
# taxvaluedollarcnt               0
# yearbuilt                       0
# taxamount                       0
# fips                            0
# dtype: int64
